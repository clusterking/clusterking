# %%
import sys
sys.path.append('..')

# %load_ext autoreload
# %autoreload 2

# %%
import cluster

from modules.plots import ClusterPlot

import sklearn
import numpy as np

# %aimport cluster

# %% [markdown]
# ## Hierarchy Clustering

# %%
hc = cluster.HierarchyCluster("../output/scan/long_g10_n10")
# Out:
# Cluster:INFO:Input file basename: '../output/scan/long_g10_n10'.
# Cluster:DEBUG:Loading scanner metadata from '/home/kilian/Documents/git_sync/B_decays_clustering/output/scan/long_g10_n10_metadata.json'.
# Cluster:DEBUG:Done.
# Cluster:DEBUG:Loading scanner data from '/home/kilian/Documents/git_sync/B_decays_clustering/output/scan/long_g10_n10_data.csv'.
# Cluster:DEBUG:Done.

# %%
hc.cluster(max_d=0.07)
# Out:
# Cluster:INFO:Performing clustering.
# Cluster:DEBUG:Building hierarchy.
# Cluster:DEBUG:Done
# Cluster:INFO:Clustering resulted in 4 clusters.
# Cluster:INFO:Done

# %%
cp = ClusterPlot(hc.df)
cp.scatter(['l', 'sl'])

# %% [markdown]
# ## Kmeans clustering

# %%
kc = cluster.KmeansCluster("../output/scan/long_g10_n10")
# Out:
# Cluster:INFO:Input file basename: '../output/scan/long_g10_n10'.
# Cluster:DEBUG:Loading scanner metadata from '/home/kilian/Documents/git_sync/B_decays_clustering/output/scan/long_g10_n10_metadata.json'.
# Cluster:DEBUG:Done.
# Cluster:DEBUG:Loading scanner data from '/home/kilian/Documents/git_sync/B_decays_clustering/output/scan/long_g10_n10_data.csv'.
# Cluster:DEBUG:Done.

# %%
kc.cluster(n_clusters=4)
# Out:
# Cluster:INFO:Performing clustering.
# Cluster:INFO:Clustering resulted in 4 clusters.
# Cluster:INFO:Done

# %%
cp = ClusterPlot(kc.df)
cp.scatter(['l', 'sl'])
